# %%
from pflotran.template import Template

# %%
dummy_config = {'template': "/Users/angus/work/hydrothermal_alteration/pflotran_model/omphalos_dev/test.in"}
template = Template(dummy_config)
# Out:
# [701 772 791] [770 789 808]

# %%
template.editable_blocks
# Out:
# {'constraint': {'initial_constraint': <omphalos.keyword_block.KeywordBlock at 0x10e793210>,
#   'inlet_constraint': <omphalos.keyword_block.KeywordBlock at 0x10f72b3d0>,
#   'empty': <omphalos.keyword_block.KeywordBlock at 0x10f72bfd0>},
#  'initial_condition': {'all': <omphalos.keyword_block.KeywordBlock at 0x10f735010>},
#  'boundary_condition': {'seafloor': <omphalos.keyword_block.KeywordBlock at 0x10f735290>,
#   'reaction_zone': <omphalos.keyword_block.KeywordBlock at 0x10f735350>},
#  'strata': {'all': <omphalos.keyword_block.KeywordBlock at 0x10f735a10>,
#   'upwelling': <omphalos.keyword_block.KeywordBlock at 0x10f7359d0>,
#   'downwelling': <omphalos.keyword_block.KeywordBlock at 0x10f735b10>,
#   'low_perm': <omphalos.keyword_block.KeywordBlock at 0x10f735d10>}}

# %%
template.verbatim
# Out:
# {1: '',
#  2: 'SIMULATION',
#  3: '  SIMULATION_TYPE SUBSURFACE',
#  4: '  PROCESS_MODELS',
#  5: '    SUBSURFACE_FLOW flow',
#  6: '      MODE TH',
#  7: '    /',
#  8: '    SUBSURFACE_TRANSPORT transport',
#  9: '      MODE GIRT',
#  10: '    /',
#  11: '  /',
#  12: 'END',
#  13: '',
#  14: 'SUBSURFACE',
#  15: '',
#  17: 'NUMERICAL_METHODS FLOW',
#  18: '  NEWTON_SOLVER',
#  19: '  /',
#  20: 'END',
#  21: '',
#  22: 'NUMERICAL_METHODS TRANSPORT',
#  23: '  NEWTON_SOLVER',
#  24: '  /',
#  25: 'END',
#  26: '',
#  27: '',
#  29: 'GRID',
#  30: '  TYPE structured',
#  31: '  ORIGIN 0.d0 0.d0 0.d0',
#  32: '  NXYZ 50 1 50',
#  33: '  BOUNDS',
#  34: '    0    0  0',
#  35: '    1500  100  1500',
#  36: '  /',
#  37: 'END',
#  38: '',
#  39: '',
#  41: 'FLUID_PROPERTY',
#  42: '  DIFFUSION_COEFFICIENT 1.d-9',
#  43: 'END',
#  44: '',
#  45: '',
#  47: 'EOS WATER',
#  48: '  DENSITY IF97',
#  49: '  ENTHALPY IF97',
#  50: 'END',
#  51: '',
#  53: 'MATERIAL_PROPERTY sheeted_dykes',
# ...

# %%
template.path = '/Users/angus/work/hydrothermal_alteration/pflotran_model/omphalos_dev/test_out.in'
template.print()
# Out:
# constraint
# initial_condition
# boundary_condition
# strata

# %%
template.editable_blocks['constraint']['inlet_constraint'].__dict__
# Out:
# {'block_type': 'CONSTRAINT',
#  'contents': {'CONSTRAINT': ['inlet_constraint'],
#   'CONCENTRATIONS': [],
#   'H+': ['8.15', 'P'],
#   'Al+++': ['0.037d-9', 'T'],
#   'O2(aq)': ['1.0d-18', 'T'],
#   'Mg++': ['52.8d-3', 'T'],
#   'Ca++': ['10.3d-3', 'T'],
#   'Fe++': ['1.0d-15', 'T'],
#   'Fe+++': ['1.0d-9', 'T'],
#   'HCO3-': ['2.06d-3', 'T'],
#   'Cl-': ['474d-3', 'Z'],
#   'K+': ['10.2d-3', 'T'],
#   'Na+': ['474d-3', 'T'],
#   'SO4--': ['28.2d-3', 'T'],
#   'SiO2(aq)': ['0.17d-3', 'T'],
#   'Ti(OH)4(aq)': ['2.09d-9', 'T'],
#   '/': []}}
